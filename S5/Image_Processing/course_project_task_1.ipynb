# %%
print("Hellow icecream")
# Out:
# Hellow icecream

# %%
a = 1
b = 2
print("Sum = ")
print(a + b)
print("a * b = ", a * b)
# Out:
# Sum =
# 3
# a * b =  2

# %%
pain = input("What is your pain?")
print("I know that that " + pain + " is very much a pain")
# Out:
# I know that that i miss her is very much a pain

# %%
for i in range(5):
    print("Gay")
i = 0
while(i <= 5):
    print("Frogs")
    i = i + 1
# Out:
# Gay
# Gay
# Gay
# Gay
# Gay
# Frogs
# Frogs
# Frogs
# Frogs
# Frogs
# Frogs

# %%
import numpy as np
import matplotlib.pyplot as plt

arr = np.array([1,4,0,2,3])
print(arr)
print("First = ", arr[0])
print("Second last = ", arr[-2])

plt.plot(arr)
plt.title("pain plot")
plt.show()
# Out:
# [1 4 0 2 3]
# First =  1
# Second last =  2

# %%
import cv2

img = cv2.imread('images\middle.jpeg')

# img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()
